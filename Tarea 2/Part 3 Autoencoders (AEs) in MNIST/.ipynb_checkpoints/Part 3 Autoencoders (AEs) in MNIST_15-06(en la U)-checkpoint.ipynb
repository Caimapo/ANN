# %%
from importlib import reload
reload(plt)
# %matplotlib notebook

# %% [markdown]
# Se cargan los datos desde keras, se normalizan las imagenes de modo que los pixeles queden descritos en el range [0,1], luegos se transforman en vectores unidimensionales y se parten en conjuntos disjuntos de entrenamiento, validación y prueba

# %%
from keras.datasets import mnist
import os
import time
import numpy as np
from keras.utils import np_utils
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
from collections import defaultdict

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255. #and x_test
x_test = x_test.astype('float32') / 255.
#Se extraen datos para hacer el set de validación
# print(x_train.shape)
# print(x_test.shape)
x_train, x_val, y_train, y_val = train_test_split(x_train,y_train, test_size=(1/6))
#como vector
Y_train = np_utils.to_categorical(y_train, 10)
Y_val = np_utils.to_categorical(y_val, 10)
Y_test = np_utils.to_categorical(y_test, 10)
print('datos de entrenamiento : '+str(x_train.shape)+' '+str(y_train.shape))
print('datos de validacion : '+str(x_val.shape)+' '+str(y_val.shape))
print('datos de pruebas : '+str(x_test.shape)+' '+str(y_test.shape))
# Out:
# datos de entrenamiento : (50000, 28, 28) (50000,)
# datos de validacion : (10000, 28, 28) (10000,)
# datos de pruebas : (10000, 28, 28) (10000,)

# %% [markdown]
# Luego se pasa a usar los datos para una red de autoencoder feed forward, en donde las capas de este son densas. Para esto se re estructuraran los datos de entradas en forma de vector, es decir la matriz de 28 × 28 pasa a ser un vector de 784 componentes.

# %%
X_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
X_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
X_val = x_val.reshape((len(x_val), np.prod(x_val.shape[1:])))

print('datos de entrenamiento : '+str(X_train.shape)+' '+str(Y_train.shape))
print('datos de validacion : '+str(X_val.shape)+' '+str(Y_val.shape))
print('datos de pruebas : '+str(X_test.shape)+' '+str(Y_test.shape))
# Out:
# datos de entrenamiento : (50000, 784) (50000, 10)
# datos de validacion : (10000, 784) (10000, 10)
# datos de pruebas : (10000, 784) (10000, 10)

# %% [markdown]
# #### Sección a) Se entrena un AE (1 hddn layer) para generar una representación de MNIST de d' = 2 ,8 ,32 ,64 . Se elije la función de perdida categorical_crossentropy   y el criterio del entrenamiento sigmoid . Determine el porcentaje de compresión obtneido y el error de reconstrucción en cada caso. Se mojra el resulta si elegiumos un funcióin de activación reulo para el encoder o decoder.
#
# ** revisar si binary-crossentroy o categorical (condiderando que trabaja con múltiples clases)
# First, we'll configure our model to use a per-pixel binary crossentropy loss
# ** Falta % de compresión, a que se refiere
#
# #### Sobre jugar con los tamaños del batch, se observa que a menor tamaño el tiempo es mayor, pero se necesitan menos epochs para coverger a un buen resultado. Con tamaños muy grandes del batch, se obtienen aun buenos resultados en los graficos, pero a la hora de gráficar, se observa resultars con el efecto de blur mucho mayor (se probo con 3x epochs que con un batch de 4, 32)

# %%
## Completar para mostrar distintos hist para graficar la perdida. 
## Mostrar la matriz de confusión para cada configuración
## sacar conclusiones
from keras.metrics import categorical_accuracy, binary_accuracy
from keras.layers import Input, Dense
from keras.models import Model
from keras.optimizers import SGD

def plot_data(models,grph):
    #Grafica loss y accuracy para varios modelos
    plt.close('all')
    #axarr.title('MSE vs Epoch')
    f, axarr = plt.subplots(grph, sharex=True, figsize=(15,15))
    f.text(0.5, 0.1, 'epochs', ha='center', va='center')
    f.text(0.06, 0.7, 'loss', ha='center', va='center', rotation='vertical')
    f.text(0.06, 0.3, 'accuracy', ha='center', va='center', rotation='vertical')
    # dict format name: [model history,model time, model score]
    for name,model in models.items():
        #print(model)
        axarr[0].plot(model[0].history['loss'], marker='o', label=name)
        axarr[1].plot(model[0].history['val_loss'], marker='o', label=str('val_')+name)
        axarr[2].plot(model[0].history['binary_accuracy'], marker='o', label=name)
        axarr[3].plot(model[0].history['val_binary_accuracy'], marker='o', label=str('val_')+name)
    f.subplots_adjust(hspace = 0, wspace = 0)
    [axarr[i].legend(loc='center left',bbox_to_anchor=(1, 0.5)) for i in range(grph)]
    [axarr[i].grid(True) for i in range(grph)]
    plt.show()
    
    
def create_model(activation1,activation2,loss,d=32):
    input_img = Input(shape=(784,))    
    encoded = Dense(d, activation=activation1)(input_img)
    decoded = Dense(784, activation=activation2)(encoded)
    autoencoder = Model(input=input_img, output=decoded)
    encoder = Model(input=input_img, output=encoded)
    encoded_input = Input(shape=(d,))
    decoder_layer = autoencoder.layers[-1]
    decoder = Model(input=encoded_input, output=decoder_layer(encoded_input))
    if loss == 'b':
        autoencoder.compile(optimizer=SGD(lr=1.0), loss='binary_crossentropy',metrics=[binary_accuracy])
    else:
        autoencoder.compile(optimizer=SGD(lr=1.0), loss='categorical_crossentropy',metrics=[binary_accuracy])
    return autoencoder, encoder, decoder

# %%
modelos = defaultdict(list)
for loss_f in ['b']:
    for activation1 in ['sigmoid','relu']:
        for activation2 in ['sigmoid','relu']:
            name = 'modelo_'+loss_f+'_'+activation1+'_'+activation2
            model, e, d = create_model(activation1,activation2,loss_f)
            #save model
            #print(os.path.join(os.getcwd(), 'exp', 'a','model_weights_'+name+'.h5'))
            model.save_weights(os.path.join(os.getcwd(), 'exp', 'a','model_weights_'+name+'.h5'))
            with open(os.path.join(os.getcwd(), 'exp', 'a', 'model_architecture_'+name+'.json'), 'w') as f:
                f.write(model.to_json())
            #
            start = time.time()
            history =model.fit(X_train, X_train,
                                           epochs=25,
                                           batch_size=128,
                                           shuffle=True,
                                           validation_data=(X_val,X_val),verbose=1)
            modelos[name].append(history)
            modelos[name].append(d)
            modelos[name].append(e)
            modelos[name].append(time.time() - start)
            score = model.evaluate(X_val,X_val)
            modelos[name].append(score)
# Out:
# c:\users\caimapo\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:33: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# c:\users\caimapo\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:34: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# c:\users\caimapo\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:37: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# C:\Users\Caimapo\Desktop\U\ML\Tarea 2\Part 3 Autoencoders (AEs) in MNIST\exp\a\model_weights_modelo_b_sigmoid_sigmoid.h5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 2s 40us/step - loss: 0.4016 - binary_accuracy: 0.7786 - val_loss: 0.2973 - val_binary_accuracy: 0.8033
# Epoch 2/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.2845 - binary_accuracy: 0.8034 - val_loss: 0.2771 - val_binary_accuracy: 0.8040
# Epoch 3/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.2738 - binary_accuracy: 0.8036 - val_loss: 0.2715 - val_binary_accuracy: 0.8040
# Epoch 4/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2700 - binary_accuracy: 0.8037 - val_loss: 0.2689 - val_binary_accuracy: 0.8041
# Epoch 5/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2681 - binary_accuracy: 0.8037 - val_loss: 0.2675 - val_binary_accuracy: 0.8037
# Epoch 6/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.2670 - binary_accuracy: 0.8038 - val_loss: 0.2666 - val_binary_accuracy: 0.8034
# Epoch 7/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.2662 - binary_accuracy: 0.8037 - val_loss: 0.2659 - val_binary_accuracy: 0.8040
# Epoch 8/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2657 - binary_accuracy: 0.8038 - val_loss: 0.2655 - val_binary_accuracy: 0.8041
# Epoch 9/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2653 - binary_accuracy: 0.8038 - val_loss: 0.2651 - val_binary_accuracy: 0.8041
# Epoch 10/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2650 - binary_accuracy: 0.8038 - val_loss: 0.2649 - val_binary_accuracy: 0.8039
# Epoch 11/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2648 - binary_accuracy: 0.8039 - val_loss: 0.2647 - val_binary_accuracy: 0.8042
# Epoch 12/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2646 - binary_accuracy: 0.8038 - val_loss: 0.2645 - val_binary_accuracy: 0.8041
# Epoch 13/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2644 - binary_accuracy: 0.8039 - val_loss: 0.2643 - val_binary_accuracy: 0.8039
# Epoch 14/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.2643 - binary_accuracy: 0.8038 - val_loss: 0.2642 - val_binary_accuracy: 0.8041
# Epoch 15/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2642 - binary_accuracy: 0.8039 - val_loss: 0.2641 - val_binary_accuracy: 0.8040
# Epoch 16/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.2641 - binary_accuracy: 0.8040 - val_loss: 0.2640 - val_binary_accuracy: 0.8037
# Epoch 17/25
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.2640 - binary_accuracy: 0.8038 - val_loss: 0.2639 - val_binary_accuracy: 0.8037
# Epoch 18/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.2639 - binary_accuracy: 0.8039 - val_loss: 0.2638 - val_binary_accuracy: 0.8037
# Epoch 19/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.2638 - binary_accuracy: 0.8037 - val_loss: 0.2638 - val_binary_accuracy: 0.8037
# Epoch 20/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2638 - binary_accuracy: 0.8039 - val_loss: 0.2637 - val_binary_accuracy: 0.8044
# Epoch 21/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.2637 - binary_accuracy: 0.8039 - val_loss: 0.2637 - val_binary_accuracy: 0.8038
# Epoch 22/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2637 - binary_accuracy: 0.8037 - val_loss: 0.2636 - val_binary_accuracy: 0.8048
# Epoch 23/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.2636 - binary_accuracy: 0.8042 - val_loss: 0.2636 - val_binary_accuracy: 0.8041
# Epoch 24/25
# 50000/50000 [==============================] - 1s 29us/step - loss: 0.2636 - binary_accuracy: 0.8037 - val_loss: 0.2635 - val_binary_accuracy: 0.8041
# Epoch 25/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2635 - binary_accuracy: 0.8040 - val_loss: 0.2635 - val_binary_accuracy: 0.8041
# 10000/10000 [==============================] - 1s 59us/step
# C:\Users\Caimapo\Desktop\U\ML\Tarea 2\Part 3 Autoencoders (AEs) in MNIST\exp\a\model_weights_modelo_b_sigmoid_relu.h5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.0018 - binary_accuracy: 0.7903 - val_loss: 1.0769 - val_binary_accuracy: 0.7843
# Epoch 2/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.0642 - binary_accuracy: 0.7761 - val_loss: 1.0544 - val_binary_accuracy: 0.7711
# Epoch 3/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.1450 - binary_accuracy: 0.7649 - val_loss: 1.3028 - val_binary_accuracy: 0.7542
# Epoch 4/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 1.3892 - binary_accuracy: 0.7470 - val_loss: 1.5172 - val_binary_accuracy: 0.7356
# Epoch 5/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.3790 - binary_accuracy: 0.7419 - val_loss: 1.1331 - val_binary_accuracy: 0.7542
# Epoch 6/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 1.2361 - binary_accuracy: 0.7480 - val_loss: 1.3026 - val_binary_accuracy: 0.7448
# Epoch 7/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.4285 - binary_accuracy: 0.7377 - val_loss: 1.5015 - val_binary_accuracy: 0.7350
# Epoch 8/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.5109 - binary_accuracy: 0.7341 - val_loss: 1.4744 - val_binary_accuracy: 0.7368
# Epoch 9/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.3496 - binary_accuracy: 0.7426 - val_loss: 0.9224 - val_binary_accuracy: 0.7668
# Epoch 10/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.9498 - binary_accuracy: 0.7624 - val_loss: 0.9896 - val_binary_accuracy: 0.7603
# Epoch 11/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.0698 - binary_accuracy: 0.7577 - val_loss: 1.1341 - val_binary_accuracy: 0.7534
# Epoch 12/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.1996 - binary_accuracy: 0.7495 - val_loss: 1.2936 - val_binary_accuracy: 0.7448
# Epoch 13/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.3567 - binary_accuracy: 0.7414 - val_loss: 1.4797 - val_binary_accuracy: 0.7341
# Epoch 14/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.5727 - binary_accuracy: 0.7281 - val_loss: 1.6248 - val_binary_accuracy: 0.7262
# Epoch 15/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 1.7246 - binary_accuracy: 0.7210 - val_loss: 1.7785 - val_binary_accuracy: 0.7185
# Epoch 16/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 1.8220 - binary_accuracy: 0.7169 - val_loss: 1.8504 - val_binary_accuracy: 0.7162
# Epoch 17/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.9403 - binary_accuracy: 0.7095 - val_loss: 2.0871 - val_binary_accuracy: 0.7030
# Epoch 18/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.2233 - binary_accuracy: 0.6938 - val_loss: 2.3388 - val_binary_accuracy: 0.6877
# Epoch 19/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4188 - binary_accuracy: 0.6832 - val_loss: 2.5099 - val_binary_accuracy: 0.6799
# Epoch 20/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.6615 - binary_accuracy: 0.6703 - val_loss: 2.8666 - val_binary_accuracy: 0.6591
# Epoch 21/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.9038 - binary_accuracy: 0.6569 - val_loss: 2.9266 - val_binary_accuracy: 0.6568
# Epoch 22/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.9719 - binary_accuracy: 0.6536 - val_loss: 2.9823 - val_binary_accuracy: 0.6530
# Epoch 23/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 3.0426 - binary_accuracy: 0.6495 - val_loss: 3.1094 - val_binary_accuracy: 0.6455
# Epoch 24/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.1026 - binary_accuracy: 0.6469 - val_loss: 3.0539 - val_binary_accuracy: 0.6506
# Epoch 25/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.1558 - binary_accuracy: 0.6440 - val_loss: 3.2313 - val_binary_accuracy: 0.6381
# 10000/10000 [==============================] - 1s 60us/step
# C:\Users\Caimapo\Desktop\U\ML\Tarea 2\Part 3 Autoencoders (AEs) in MNIST\exp\a\model_weights_modelo_b_relu_sigmoid.h5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.3176 - binary_accuracy: 0.7724 - val_loss: 0.2612 - val_binary_accuracy: 0.7969
# Epoch 2/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2428 - binary_accuracy: 0.7973 - val_loss: 0.2238 - val_binary_accuracy: 0.7985
# Epoch 3/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.2103 - binary_accuracy: 0.7985 - val_loss: 0.1984 - val_binary_accuracy: 0.7997
# Epoch 4/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1911 - binary_accuracy: 0.8005 - val_loss: 0.1834 - val_binary_accuracy: 0.8015
# Epoch 5/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.1785 - binary_accuracy: 0.8025 - val_loss: 0.1726 - val_binary_accuracy: 0.8037
# Epoch 6/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1688 - binary_accuracy: 0.8041 - val_loss: 0.1639 - val_binary_accuracy: 0.8051
# Epoch 7/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.1608 - binary_accuracy: 0.8055 - val_loss: 0.1566 - val_binary_accuracy: 0.8061
# Epoch 8/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1540 - binary_accuracy: 0.8066 - val_loss: 0.1503 - val_binary_accuracy: 0.8071
# Epoch 9/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1482 - binary_accuracy: 0.8076 - val_loss: 0.1449 - val_binary_accuracy: 0.8079
# Epoch 10/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1431 - binary_accuracy: 0.8084 - val_loss: 0.1402 - val_binary_accuracy: 0.8086
# Epoch 11/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.1387 - binary_accuracy: 0.8090 - val_loss: 0.1360 - val_binary_accuracy: 0.8092
# Epoch 12/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1347 - binary_accuracy: 0.8096 - val_loss: 0.1322 - val_binary_accuracy: 0.8100
# Epoch 13/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1310 - binary_accuracy: 0.8102 - val_loss: 0.1286 - val_binary_accuracy: 0.8105
# Epoch 14/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1275 - binary_accuracy: 0.8107 - val_loss: 0.1252 - val_binary_accuracy: 0.8109
# Epoch 15/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1243 - binary_accuracy: 0.8112 - val_loss: 0.1222 - val_binary_accuracy: 0.8114
# Epoch 16/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1213 - binary_accuracy: 0.8116 - val_loss: 0.1193 - val_binary_accuracy: 0.8118
# Epoch 17/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1187 - binary_accuracy: 0.8119 - val_loss: 0.1169 - val_binary_accuracy: 0.8121
# Epoch 18/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.1164 - binary_accuracy: 0.8122 - val_loss: 0.1147 - val_binary_accuracy: 0.8123
# Epoch 19/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.1143 - binary_accuracy: 0.8124 - val_loss: 0.1127 - val_binary_accuracy: 0.8126
# Epoch 20/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.1125 - binary_accuracy: 0.8126 - val_loss: 0.1110 - val_binary_accuracy: 0.8128
# Epoch 21/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.1109 - binary_accuracy: 0.8128 - val_loss: 0.1095 - val_binary_accuracy: 0.8130
# Epoch 22/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1095 - binary_accuracy: 0.8129 - val_loss: 0.1082 - val_binary_accuracy: 0.8130
# Epoch 23/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.1083 - binary_accuracy: 0.8131 - val_loss: 0.1070 - val_binary_accuracy: 0.8131
# Epoch 24/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1072 - binary_accuracy: 0.8132 - val_loss: 0.1059 - val_binary_accuracy: 0.8133
# Epoch 25/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.1062 - binary_accuracy: 0.8133 - val_loss: 0.1050 - val_binary_accuracy: 0.8134
# 10000/10000 [==============================] - 1s 60us/step
# C:\Users\Caimapo\Desktop\U\ML\Tarea 2\Part 3 Autoencoders (AEs) in MNIST\exp\a\model_weights_modelo_b_relu_relu.h5
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 2s 30us/step - loss: 2.3243 - binary_accuracy: 0.7751 - val_loss: 2.3116 - val_binary_accuracy: 0.7809
# Epoch 2/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.1882 - binary_accuracy: 0.7806 - val_loss: 0.8376 - val_binary_accuracy: 0.7936
# Epoch 3/25
# 50000/50000 [==============================] - 1s 28us/step - loss: 0.5157 - binary_accuracy: 0.8009 - val_loss: 0.4426 - val_binary_accuracy: 0.7998
# Epoch 4/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.4312 - binary_accuracy: 0.7975 - val_loss: 0.4195 - val_binary_accuracy: 0.7956
# Epoch 5/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.4225 - binary_accuracy: 0.7953 - val_loss: 0.4192 - val_binary_accuracy: 0.7929
# Epoch 6/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.4282 - binary_accuracy: 0.7951 - val_loss: 0.4246 - val_binary_accuracy: 0.7956
# Epoch 7/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.4378 - binary_accuracy: 0.7962 - val_loss: 0.4420 - val_binary_accuracy: 0.7964
# Epoch 8/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.4401 - binary_accuracy: 0.7949 - val_loss: 0.4481 - val_binary_accuracy: 0.7932
# Epoch 9/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.4499 - binary_accuracy: 0.7952 - val_loss: 0.4435 - val_binary_accuracy: 0.7965
# Epoch 10/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.4497 - binary_accuracy: 0.7966 - val_loss: 0.4644 - val_binary_accuracy: 0.7963
# Epoch 11/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.4954 - binary_accuracy: 0.7945 - val_loss: 0.5052 - val_binary_accuracy: 0.7932
# Epoch 12/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.4902 - binary_accuracy: 0.7942 - val_loss: 0.4801 - val_binary_accuracy: 0.7949
# Epoch 13/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.4704 - binary_accuracy: 0.7943 - val_loss: 0.4540 - val_binary_accuracy: 0.7955
# Epoch 14/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.4533 - binary_accuracy: 0.7942 - val_loss: 0.4437 - val_binary_accuracy: 0.7934
# Epoch 15/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.4599 - binary_accuracy: 0.7922 - val_loss: 0.4552 - val_binary_accuracy: 0.7901
# Epoch 16/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.4999 - binary_accuracy: 0.7888 - val_loss: 0.5820 - val_binary_accuracy: 0.7837
# Epoch 17/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.5704 - binary_accuracy: 0.7854 - val_loss: 0.5767 - val_binary_accuracy: 0.7855
# Epoch 18/25
# 50000/50000 [==============================] - 1s 27us/step - loss: 0.5645 - binary_accuracy: 0.7887 - val_loss: 0.5554 - val_binary_accuracy: 0.7906
# Epoch 19/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.5403 - binary_accuracy: 0.7910 - val_loss: 0.5280 - val_binary_accuracy: 0.7901
# Epoch 20/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.5031 - binary_accuracy: 0.7912 - val_loss: 0.5078 - val_binary_accuracy: 0.7906
# Epoch 21/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.5231 - binary_accuracy: 0.7903 - val_loss: 0.5333 - val_binary_accuracy: 0.7920
# Epoch 22/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.5339 - binary_accuracy: 0.7919 - val_loss: 0.5332 - val_binary_accuracy: 0.7920
# Epoch 23/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.5338 - binary_accuracy: 0.7920 - val_loss: 0.5332 - val_binary_accuracy: 0.7920
# Epoch 24/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.5338 - binary_accuracy: 0.7919 - val_loss: 0.5331 - val_binary_accuracy: 0.7920
# Epoch 25/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.5338 - binary_accuracy: 0.7920 - val_loss: 0.5331 - val_binary_accuracy: 0.7920
# 10000/10000 [==============================] - 1s 57us/step

# %%
plot_data(modelos,4)
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
# Se experimenta con el cambio de dimension, con distintas configuraciones
# con la capa de activacion del decoder como sigmoid, dado que relu presenta resultados 
# no atrayentes.

modelos_d = defaultdict(list)
for dimension in [8,16,32,64,128]:
    for activation1 in ['sigmoid','relu']:
        for activation2 in ['sigmoid']:
            name = 'modelo_'+loss_f+'_'+activation1+'_'+activation2+'_'+str(dimension)
            model, e, d = create_model(activation1,activation2,'b',dimension)
            #save model
            model.save_weights(os.path.join(os.getcwd(), 'exp', 'a2','model_weights_'+name+'.h5'))
            with open(os.path.join(os.getcwd(), 'exp', 'a2', 'model_architecture_'+name+'.json'), 'w') as f:
                f.write(model.to_json())
            #
            start = time.time()
            history =model.fit(X_train, X_train,
                                           epochs=25,
                                           batch_size=128,
                                           shuffle=True,
                                           validation_data=(X_val,X_val),verbose=0)
            modelos_d[name].append(history)
            modelos_d[name].append(d)
            modelos_d[name].append(e)
            modelos_d[name].append(time.time() - start)
            score = model.evaluate(X_val,X_val)
            modelos_d[name].append(score)
# Out:
# c:\users\caimapo\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:33: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# c:\users\caimapo\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:34: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# c:\users\caimapo\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:37: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# 10000/10000 [==============================] - 1s 58us/step
# 10000/10000 [==============================] - 1s 57us/step
# 10000/10000 [==============================] - 1s 56us/step
# 10000/10000 [==============================] - 0s 44us/step
# 10000/10000 [==============================] - 1s 65us/step
# 10000/10000 [==============================] - 1s 59us/step
# 10000/10000 [==============================] - 1s 65us/step
# 10000/10000 [==============================] - 1s 70us/step
# 10000/10000 [==============================] - 1s 74us/step
# 10000/10000 [==============================] - 1s 74us/step

# %% [markdown]
# #### Sección b) Se comparan visialmente la reconstrucción que logra realizar el autoencoder. Determinar si la percepción visual se corresponde con el error de reconstrucción que se observa.

# %%
def plot_im(model,name,X):
    print(name)
    with open(os.path.join(os.getcwd(), 'exp', 'a', 'model_architecture_'+name+'.json'), 'r') as f:
        autoencoder = model_from_json(f.read())
    autoencoder.load_weights(os.path.join(os.getcwd(), 'exp', 'a','model_weights_'+name+'.h5'))

    encoded_test = model[name][2].predict(X)
    decoded_test = model[name][1].predict(encoded_test)
    
    n = 20
    plt.figure(figsize=(20, 4))
    for i in range(n):
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(x_test[i].reshape(28, 28),cmap='gray')
        plt.title('original')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        ax = plt.subplot(2, n, i + 1 + n)
        plt.title('decoded')
        plt.imshow(decoded_test[i].reshape(28, 28),cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
## verificar que encoder y decoder sean los mejores del punto anterior.
## mostra graficamente para las cuatro configuraciones del punto anterior
## seria interesante ver la imagen pequeña
from keras.models import load_model, model_from_json
#load other stuff ...
for loss_f in ['b']:
    for activation1 in ['sigmoid','relu']:
        for activation2 in ['sigmoid','relu']:
            name = 'modelo_'+loss_f+'_'+activation1+'_'+activation2
            plot_im(modelos,name,X_test)
# Out:
# modelo_b_sigmoid_sigmoid
# modelo_b_sigmoid_relu
# modelo_b_relu_sigmoid
# modelo_b_relu_relu

# %% [markdown]
# #### Sección c) Se verifica la calidad de la representación obtenida, para ello se construye un clasificador kNN.

# %%
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
def calidad(model,name):
    print(name)
    with open(os.path.join(os.getcwd(), 'exp','a','model_architecture_'+str(name)+'.json'), 'r') as f:
        autoencoder = model_from_json(f.read())
    autoencoder.load_weights(os.path.join(os.getcwd(), 'exp','a','model_weights_'+str(name)+'.h5'))
    pca = PCA(n_components=10)
    #PCA
    pca.fit(X_train)
    pca_train = pca.transform(X_train)
    pca_test = pca.transform(X_test)
    #AUTOENCODER
    encoded_train = model[name][2].predict(X_train)
    encoded_test = model[name][2].predict(X_test)
    #CLASIFICATION
    clf = KNeighborsClassifier(10)
    clf.fit(pca_train, Y_train)
    print ('Classification Accuracy PCA %.2f' % clf.score(pca_test,Y_test))
    clf = KNeighborsClassifier(10)
    clf.fit(encoded_train, Y_train)
    print ('Classification Accuracy %.2f' % clf.score(encoded_test,Y_test))

# %%
for loss_f in ['b']:
    for activation1 in ['sigmoid','relu']:
        for activation2 in ['sigmoid','relu']:
            name = 'modelo_'+loss_f+'_'+activation1+'_'+activation2
            calidad(modelos,name)
# Out:
# modelo_b_sigmoid_sigmoid
# Classification Accuracy PCA 0.91
# Classification Accuracy 0.53
# modelo_b_sigmoid_relu
# Classification Accuracy PCA 0.91
# Classification Accuracy 0.69
# modelo_b_relu_sigmoid
# Classification Accuracy PCA 0.91
# Classification Accuracy 0.95
# modelo_b_relu_relu
# Classification Accuracy PCA 0.91
# Classification Accuracy 0.00

# %% [markdown]
# Falta colocar la conclusión de que AE es peor de KNN (sería interesante poder justificar porque?)
#
# ** Quedo que el modelo relu-sigmoid obtiene mejor accuracy con respecto a PCA.

# %% [markdown]
# #### Sección d) Deep encoding, se experimenta el uso de más de dos capas ocultas para demostrar que mejora la compresión obtenida por PCA, utilizando el mismo número de dimensiones. Para ello se prueba con $d \in [2,4,8,16]$ y distintas profundidades $L \in [2,3,4]$ y se compara el desempeño tanto en el error de reconstrucción como en clasificación via kNN de cada representación

# %%
def get_numeros(numero,dimension):
    if(numero == 2):
        return [dimension, 1000]
    if(numero == 3):
        return [dimension, 500, 1000]
    if(numero == 4):
        return [dimension, 250, 500, 1000]
# Ejemplo de input ['sigmoid','relu'],['sigmoid','sigmoid'],[1000,250],2
def create_deep_model(activation_e, activation_d, dimlist, depth=2):
    input_img = Input(shape=(784,))
    encoded = Dense(dimlist[::-1][0], activation=activation_e[0])(input_img)
    #print('e',dimlist[::-1][0],activation_e[0])
    for i in range(1,depth):
        #print('e',dimlist[::-1][i],activation_e[i])  
        encoded = Dense(dimlist[::-1][i], activation=activation_e[i])(encoded)
    decoded = Dense(dimlist[1:][0], activation=activation_d[0])(encoded)
    #print('d',dimlist[1:][0],activation_d[0])
    for i in range(1,depth):
        if(i+1 == depth):
            #print('d',784,activation_d[::-1][:depth][::-1][i])
            decoded = Dense(784, activation=activation_d[::-1][:depth][::-1][i])(decoded)
        else:
            #print('d',dimlist[1:][i],activation_d[::-1][:depth][::-1][i])
            decoded = Dense(dimlist[i], activation=activation_d[i])(decoded)
    autoencoder = Model(input= input_img, output= decoded)
    encoder = Model(input= input_img, output= encoded)
    encoded_input = Input(shape=(dimlist[0],))
    decoder_layer = autoencoder.layers[-depth](encoded_input)        
    for i in range(1,depth):
        decoder_layer = autoencoder.layers[(-depth)+i](decoder_layer)
    decorder = Model(input= encoded_input,
                     output= decoder_layer)
    autoencoder.compile(optimizer=SGD(lr=1.0),
                        loss='binary_crossentropy',
                        metrics=[binary_accuracy])
    return autoencoder, encoder, decorder

# %%
modelos_profundos = defaultdict(list)
#activations
#activations = ? 17 combinaciones
encoder_activation = ['relu', 'relu', 'relu', 'relu']
decoder_activation = ['relu', 'relu', 'relu', 'sigmoid']
# dimension es el target
for dimension in [2, 4, 8, 16]:
    for layer in [2,3,4]:
            layers = get_numeros(layer,dimension)
            name = 'modelo_'+str(layer)+'-layer_'+str(dimension)+'-targetdim'
            print(name)
            model, e, d =create_deep_model(encoder_activation, 
                                            decoder_activation,
                                            layers, 
                                            layer)
            model.save_weights(os.path.join(os.getcwd(), 'exp','d','weights_'+name+'.h5'))
            with open(os.path.join(os.getcwd(), 'exp','d','architecture_'+name+'.json'), 'w') as f:
                f.write(model.to_json())
            start = time.time()
            history = model.fit(X_train, X_train,
                               epochs = 25,
                               batch_size= 128,
                               shuffle= True,
                               validation_data = (X_val, X_val), verbose = 0)
            modelos_profundos[name].append(history)
            modelos_profundos[name].append(d)
            modelos_profundos[name].append(e)
            modelos_profundos[name].append(time.time() - start)
            score = model.evaluate(X_val,X_val)
            modelos_profundos[name].append(score)
# Out:
# modelo_2-layer_2-targetdim
# c:\users\caimapo\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:25: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# c:\users\caimapo\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# c:\users\caimapo\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:32: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# 10000/10000 [==============================] - 1s 64us/step
# modelo_3-layer_2-targetdim
# 10000/10000 [==============================] - 1s 57us/step
# modelo_4-layer_2-targetdim
# 10000/10000 [==============================] - 1s 66us/step
# modelo_2-layer_4-targetdim
# 10000/10000 [==============================] - 1s 61us/step
# modelo_3-layer_4-targetdim
# 10000/10000 [==============================] - 1s 64us/step
# modelo_4-layer_4-targetdim
# 10000/10000 [==============================] - 1s 64us/step
# modelo_2-layer_8-targetdim
# 10000/10000 [==============================] - 1s 59us/step
# modelo_3-layer_8-targetdim
# 10000/10000 [==============================] - 1s 64us/step
# modelo_4-layer_8-targetdim
# 10000/10000 [==============================] - 1s 68us/step
# modelo_2-layer_16-targetdim
# 10000/10000 [==============================] - 1s 63us/step
# modelo_3-layer_16-targetdim
# 10000/10000 [==============================] - 1s 65us/step
# modelo_4-layer_16-targetdim
# 10000/10000 [==============================] - 1s 69us/step

# %%
def plot_im(model,name,X):
    print(name)
    with open(os.path.join(os.getcwd(), 'exp', 'd', 'architecture_'+name+'.json'), 'r') as f:
        autoencoder = model_from_json(f.read())
    autoencoder.load_weights(os.path.join(os.getcwd(), 'exp', 'd','weights_'+name+'.h5'))

    encoded_test = model[name][2].predict(X)
    decoded_test = model[name][1].predict(encoded_test)
    
    n = 20
    plt.figure(figsize=(20, 4))
    for i in range(n):
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(x_test[i].reshape(28, 28),cmap='gray')
        plt.title('original')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        ax = plt.subplot(2, n, i + 1 + n)
        plt.title('decoded')
        plt.imshow(decoded_test[i].reshape(28, 28),cmap='gray')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
for dimension in [2, 4, 8, 16]:
    for layer in [2,3,4]:
            layers = get_numeros(layer,dimension)
            name = 'modelo_'+str(layer)+'-layer_'+str(dimension)+'-targetdim'
            plot_im(modelos_profundos,name,X_test)
# Out:
# modelo_2-layer_2-targetdim
# modelo_3-layer_2-targetdim
# modelo_4-layer_2-targetdim
# modelo_2-layer_4-targetdim
# modelo_3-layer_4-targetdim
# modelo_4-layer_4-targetdim
# modelo_2-layer_8-targetdim
# modelo_3-layer_8-targetdim
# modelo_4-layer_8-targetdim
# modelo_2-layer_16-targetdim
# modelo_3-layer_16-targetdim
# modelo_4-layer_16-targetdim

# %%
plot_data(modelos_profundos,4)
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %% [markdown]
# #### Sección e) Se elije una de las representaciones anteriores y se visualizan usando la herramienta TSNE disponible en la librería sklearn. Para proceder con una comparación cualitativa de los resultados obtenidos mediante PCA y AE.

# %%
nplot=5000 #warning: mind your memory!
encoded_train = encoder.predict(x_train[:nplot])
from sklearn.manifold import TSNE
model = TSNE(n_components=2, random_state=0)
encoded_train = model.fit_transform(encoded_train)
plt.figure(figsize=(10, 10))
colors={0:'b',1:'g',2:'r',3:'c',4:'m',5:'y',6:'k',7:'orange',8:'darkgreen',9:'maroon'}
markers={0:'o',1:'+',2: 'v',3:'<',4:'>',5:'^',6:'s',7:'p',8:'*',9:'x'}
for idx in xrange(0,nplot):
    label = y_train[idx]
    line = plt.plot(encoded_train[idx][0], encoded_train[idx][1],
        color=colors[label], marker=markers[label], markersize=6)
pca_train = pca.transform(x_train)
encoded_train = pca_train[:nplot]
... #plot PCA

# %% [markdown]
# #### Sección f) Por ultimo se modifica el primer autoencoder (a) para trabajar directamente sobre las  imágenes de MNIST, sin tratarlas como vectores, sino como matrices de tamaño 1 x 28 x 28. Es posible utilizando capas convolucionales para definir el Encoder y el Decoder.

# %%
X_train_ = x_train.astype('float32') / 255.
X_test_ = x_test.astype('float32') / 255.
X_train_ = np.reshape(x_train, (len(x_train), 28, 28, 1)) #modify for th dim ordering
X_test_ = np.reshape(x_test, (len(x_test), 28, 28, 1))
input_img_ = Input(shape=(28, 28, 1))
x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img_)
x = MaxPooling2D((2, 2), border_mode='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)
autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')
autoencoder.summary()
