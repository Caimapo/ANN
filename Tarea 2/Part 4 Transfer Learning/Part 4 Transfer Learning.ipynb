# %% [markdown]
# # Tarea 2 - Parte 4
# # INF477 Redes Neuronales Artificiales I-2018
#
# Profesor: Dr. Ricardo Ñanculef --
# Ayudante: Francisco Mena
#
# Alumnos:
# - Jose Caimapo, jose.caimapo.12@sansano.usm.cl
#
# - Eliana Providel Godoy, eprovide@inf.utfsm.cl

# %% [markdown]
# <h1>Tabla de Contenidos<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Tarea-2---Parte-4" data-toc-modified-id="Tarea-2---Parte-4-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Tarea 2 - Parte 4</a></span></li><li><span><a href="#INF477-Redes-Neuronales-Artificiales-I-2018" data-toc-modified-id="INF477-Redes-Neuronales-Artificiales-I-2018-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>INF477 Redes Neuronales Artificiales I-2018</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Sección-a)-Entrene-una-red-neuronal-convolucional-como-se-presenta-en-el-código-a-continuación-durante-15-epochs,-realizando-un-gráfico-de-evolución-de-la-función-de-pérdida-y-de-la-exactitud-del-algoritmo-(accuracy)-sobre-ambos-conjuntos,-entrenamiento-y-pruebas.-Comente-sobre-el-tiempo-de-ejecución-de-este-entrenamiento.-Reporte-el-accuracy-del-modelo-final-sobre-el-conjunto-de-pruebas." data-toc-modified-id="Sección-a)-Entrene-una-red-neuronal-convolucional-como-se-presenta-en-el-código-a-continuación-durante-15-epochs,-realizando-un-gráfico-de-evolución-de-la-función-de-pérdida-y-de-la-exactitud-del-algoritmo-(accuracy)-sobre-ambos-conjuntos,-entrenamiento-y-pruebas.-Comente-sobre-el-tiempo-de-ejecución-de-este-entrenamiento.-Reporte-el-accuracy-del-modelo-final-sobre-el-conjunto-de-pruebas.-2.0.0.1"><span class="toc-item-num">2.0.0.1&nbsp;&nbsp;</span>Sección a) Entrene una red neuronal convolucional como se presenta en el código a continuación durante 15 <em>epochs</em>, realizando un gráfico de evolución de la función de pérdida y de la exactitud del algoritmo (<em>accuracy</em>) sobre ambos conjuntos, entrenamiento y pruebas. Comente sobre el tiempo de ejecución de este entrenamiento. Reporte el <em>accuracy</em> del modelo final sobre el conjunto de pruebas.</a></span></li><li><span><a href="#Sección-b)-Debido-al-comportamiento-de-las-curvas-de-entrenamiento,-claramente-se-ve-que-se-necesita-un-regularizador.-Experimente-utilizando-Dropout-con-una-tasa-de-0.25-en-las-tandas-convolucionales,-elija-donde-situarlo,-luego-de-la-primera-convolución,-después-de-la-segunda,-solamente-después-del-pooling,-en-todas-o-alguna-forma-que-le-parezca-conveniente,-de-argumentos-de-ello.-La-idea-es-que-se-forme-una-idea-de-dónde-conviene-colocar-el-regularizador-y-porqué." data-toc-modified-id="Sección-b)-Debido-al-comportamiento-de-las-curvas-de-entrenamiento,-claramente-se-ve-que-se-necesita-un-regularizador.-Experimente-utilizando-Dropout-con-una-tasa-de-0.25-en-las-tandas-convolucionales,-elija-donde-situarlo,-luego-de-la-primera-convolución,-después-de-la-segunda,-solamente-después-del-pooling,-en-todas-o-alguna-forma-que-le-parezca-conveniente,-de-argumentos-de-ello.-La-idea-es-que-se-forme-una-idea-de-dónde-conviene-colocar-el-regularizador-y-porqué.-2.0.0.2"><span class="toc-item-num">2.0.0.2&nbsp;&nbsp;</span>Sección b) Debido al comportamiento de las curvas de entrenamiento, claramente se ve que se necesita un regularizador. Experimente utilizando Dropout con una tasa de 0.25 en las tandas convolucionales, elija donde situarlo, luego de la primera convolución, después de la segunda, solamente después del <em>pooling</em>, en todas o alguna forma que le parezca conveniente, de argumentos de ello. La idea es que se forme una idea de dónde conviene colocar el regularizador y porqué.</a></span></li><li><span><a href="#Sección-c)-Como-pre-entrenamiento-de-la-misma-red-definida-en-a)-de-una-manera-no-supervisada-se-trabajará-con-un-autoencoder-convolucional,-el-cual-no-necesita-etiqueta-de-los-datos-por-lo-que-se-puede-aprovechar-de-transferir-lo-aprendido-con-datos-sin-conocer-si-pertenecen-a-la-misma-categoría-o-no.-Comente-y-analice-si-esto-mejora-lo-visto-en-a).-Utilice-todas-las-imágenes-no-etiquetadas-que-desee." data-toc-modified-id="Sección-c)-Como-pre-entrenamiento-de-la-misma-red-definida-en-a)-de-una-manera-no-supervisada-se-trabajará-con-un-autoencoder-convolucional,-el-cual-no-necesita-etiqueta-de-los-datos-por-lo-que-se-puede-aprovechar-de-transferir-lo-aprendido-con-datos-sin-conocer-si-pertenecen-a-la-misma-categoría-o-no.-Comente-y-analice-si-esto-mejora-lo-visto-en-a).-Utilice-todas-las-imágenes-no-etiquetadas-que-desee.-2.0.0.3"><span class="toc-item-num">2.0.0.3&nbsp;&nbsp;</span>Sección c) Como pre entrenamiento de la misma red definida en a) de una manera no supervisada se trabajará con un autoencoder convolucional, el cual no necesita etiqueta de los datos por lo que se puede aprovechar de transferir lo aprendido con datos sin conocer si pertenecen a la misma categoría o no. Comente y analice si esto mejora lo visto en a). <em>Utilice todas las imágenes no etiquetadas que desee</em>.</a></span></li><li><span><a href="#Sección-d)-Otra-forma-de-hacer-lo-que-se-conoce-como-transfer-learning-es-utilizar-el-conocimiento-(los-parámetros)-aprendido-por-una-red-entrenada-con-millones-de-imágenes,-y-tomar-estos-parámetros-como-los-pre-entrenados.-Para-esto-se-utilizará-el-modelo-VGG16-[7]-proporcionado-a-través-de-la-interfaz-de-keras.-Visualice-el-modelo-y-sus-23-capas.-Para-esta-instancia-se-utilizará-todo-lo-aprendido-por-las-capas-convolucionales,-es-decir,-se-eliminan-las-capas-densas-del-modelo-y-se-agregan-unas-nuevas-a-ser-entrenadas-desde-cero." data-toc-modified-id="Sección-d)-Otra-forma-de-hacer-lo-que-se-conoce-como-transfer-learning-es-utilizar-el-conocimiento-(los-parámetros)-aprendido-por-una-red-entrenada-con-millones-de-imágenes,-y-tomar-estos-parámetros-como-los-pre-entrenados.-Para-esto-se-utilizará-el-modelo-VGG16-[7]-proporcionado-a-través-de-la-interfaz-de-keras.-Visualice-el-modelo-y-sus-23-capas.-Para-esta-instancia-se-utilizará-todo-lo-aprendido-por-las-capas-convolucionales,-es-decir,-se-eliminan-las-capas-densas-del-modelo-y-se-agregan-unas-nuevas-a-ser-entrenadas-desde-cero.-2.0.0.4"><span class="toc-item-num">2.0.0.4&nbsp;&nbsp;</span>Sección d) Otra forma de hacer lo que se conoce como <em>transfer learning</em> es utilizar el conocimiento (los parámetros) aprendido por una red entrenada con millones de imágenes, y tomar estos parámetros como los pre entrenados. Para esto se utilizará el modelo VGG16 [7] proporcionado a través de la interfaz de keras. Visualice el modelo y sus 23 capas. Para esta instancia se utilizará todo lo aprendido por las capas convolucionales, es decir, se eliminan las capas densas del modelo y se agregan unas nuevas a ser entrenadas desde cero.</a></span></li><li><span><a href="#Sección-e)-Entrene-esta-red-agregando-una-capa-densa-de-1024-neuronas-seguido-de-un-dropout-de-0.5,-finalmente-es-necesario-agregar-la-capa-de-clasificación-para-las-100-clases.-Utilice-la-misma-configuración-del-optimizador-para-que-las-comparaciones-sean-válidas.-Entrene-unicamente-por-10-epochs-¿Qué-sucede?-Comente." data-toc-modified-id="Sección-e)-Entrene-esta-red-agregando-una-capa-densa-de-1024-neuronas-seguido-de-un-dropout-de-0.5,-finalmente-es-necesario-agregar-la-capa-de-clasificación-para-las-100-clases.-Utilice-la-misma-configuración-del-optimizador-para-que-las-comparaciones-sean-válidas.-Entrene-unicamente-por-10-epochs-¿Qué-sucede?-Comente.-2.0.0.5"><span class="toc-item-num">2.0.0.5&nbsp;&nbsp;</span>Sección e) Entrene esta red agregando una capa densa de 1024 neuronas seguido de un dropout de 0.5, finalmente es necesario agregar la capa de clasificación para las 100 clases. Utilice la misma configuración del optimizador para que las comparaciones sean válidas. Entrene unicamente por 10 <em>epochs</em> ¿Qué sucede? Comente.</a></span></li><li><span><a href="#Sección-f)" data-toc-modified-id="Sección-f)-2.0.0.6"><span class="toc-item-num">2.0.0.6&nbsp;&nbsp;</span>Sección f)</a></span></li><li><span><a href="#Sección-g)" data-toc-modified-id="Sección-g)-2.0.0.7"><span class="toc-item-num">2.0.0.7&nbsp;&nbsp;</span>Sección g)</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %%
import matplotlib.pyplot as plt
import keras
from keras.models import Model
from keras.datasets import cifar100
from keras.optimizers import SGD,Adam
from keras.applications import VGG16
from keras.layers import Input
from keras.models import Model

import time
import os
from collections import defaultdict
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = cifar100.load_data(label_mode='fine')

# %%
y_train = keras.utils.to_categorical(y_train, num_classes=100)
y_test = keras.utils.to_categorical(y_test, num_classes=100)
x_train = x_train/255.0
x_test = x_test/255.0

# %%
[print(i.shape) for i in [x_train,y_train,x_test,y_test]]
# Out:
# (50000, 32, 32, 3)
# (50000, 100)
# (10000, 32, 32, 3)
# (10000, 100)
# [None, None, None, None]

# %% [markdown]
# #### Sección a) Entrene una red neuronal convolucional como se presenta en el código a continuación durante 15 *epochs*, realizando un gráfico de evolución de la función de pérdida y de la exactitud del algoritmo (*accuracy*) sobre ambos conjuntos, entrenamiento y pruebas. Comente sobre el tiempo de ejecución de este entrenamiento. Reporte el *accuracy* del modelo final sobre el conjunto de pruebas.

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,Dropout
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',input_shape=x_train.shape[1:],activation='relu'))
model.add(Conv2D(32, (3, 3),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3),padding='same',activation='relu'))
model.add(Conv2D(64, (3, 3),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(1024,activation='relu'))
model.add(Dropout(0.5))
#El error era porque faltaba la capa de salida, por lo cual se agrega una softmax de 100 dado a las 100 categorias
model.add(Dense(100,activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# ...

# %%
history = defaultdict(list)

# %%
optimizer_ = SGD(lr=0.01,momentum=0.9)
model.compile(loss='categorical_crossentropy', optimizer=optimizer_, metrics=['accuracy'])
start = time.time()
history['model_a'].append(model.fit(x_train, y_train, batch_size=128,epochs=15,verbose=1, validation_data=(x_test,y_test)))
end = time.time()
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 133s 3ms/step - loss: 4.3473 - acc: 0.0438 - val_loss: 3.9657 - val_acc: 0.0955
# Epoch 2/15
# 50000/50000 [==============================] - 8s 161us/step - loss: 3.8057 - acc: 0.1224 - val_loss: 3.4999 - val_acc: 0.1809
# Epoch 3/15
# 50000/50000 [==============================] - 8s 161us/step - loss: 3.4715 - acc: 0.1781 - val_loss: 3.1850 - val_acc: 0.2356
# Epoch 4/15
# 50000/50000 [==============================] - 8s 162us/step - loss: 3.1528 - acc: 0.2352 - val_loss: 2.9594 - val_acc: 0.2825
# Epoch 5/15
# 50000/50000 [==============================] - 8s 161us/step - loss: 2.8835 - acc: 0.2878 - val_loss: 2.7448 - val_acc: 0.3198
# Epoch 6/15
# 50000/50000 [==============================] - 8s 161us/step - loss: 2.6406 - acc: 0.3341 - val_loss: 2.6044 - val_acc: 0.3486
# Epoch 7/15
# ...

# %%
score = model.evaluate(x_test, y_test,verbose=0)
history['model_a'].append(score[1])
history['model_a'].append(end-start)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.4128

# %%
plt.close()
fig, (loss_ax, acc_ax) = plt.subplots(1,2,sharex=True,figsize=(16,4))
loss_ax.scatter(history['model_a'][0].epoch,history['model_a'][0].history['loss'])
loss_ax.scatter(history['model_a'][0].epoch,history['model_a'][0].history['val_loss'])
loss_ax.plot(history['model_a'][0].history['loss'], label='loss')
loss_ax.plot(history['model_a'][0].history['val_loss'], label='val_loss')
acc_ax.scatter(history['model_a'][0].epoch,history['model_a'][0].history['acc'])
acc_ax.scatter(history['model_a'][0].epoch,history['model_a'][0].history['val_acc'])
acc_ax.plot(history['model_a'][0].history['acc'], label='acc')
acc_ax.plot(history['model_a'][0].history['val_acc'], label='val_acc')
acc_ax.legend()
loss_ax.legend()
plt.show()

# %% [markdown]
# Este sera nuestro modelo cero, para realizar las comparaciones de diferentes modelos. Se presenta una accuracy de 0.4 el cual se intentara mejorar

# %% [markdown]
# #### Sección b) Debido al comportamiento de las curvas de entrenamiento, claramente se ve que se necesita un regularizador. Experimente utilizando Dropout con una tasa de 0.25 en las tandas convolucionales, elija donde situarlo, luego de la primera convolución, después de la segunda, solamente después del *pooling*, en todas o alguna forma que le parezca conveniente, de argumentos de ello. La idea es que se forme una idea de dónde conviene colocar el regularizador y porqué.

# %%
def plot_data(history,title):
    plt.close('all')
    #f, axarr = plt.subplots(2, shrex=True,figsize=(8,8))
    f, axarr = plt.subplots(2,2,sharex='col', sharey='row',figsize=(15,15))
    #axarr.title('MSE vs Epoch')
    cnt = 0
    for i in range(2):
        for j in range(2):
            axarr[i,j].grid(True)
            axarr[i,j].plot(history[cnt].history['loss'])
            axarr[i,j].plot(history[cnt].history['val_loss'])
            axarr[i,j].legend(['entrenamiento', 'prueba'], loc='upper right')
            axarr[i,j].text(1,2,'caso '+str(cnt+1))
            cnt = cnt + 1
            axarr[j,0].set_ylabel('loss')
    #axarr[0,0].set_xlabel('common xlabel')
        axarr[1,i].set_xlabel('epochs')
    #plt.ylim(ymin=0, ymax=1)
    f.subplots_adjust(hspace = 0, wspace = 0)
    plt.suptitle(title, fontsize=16)
    #plt.legend(['entrenamiento', 'prueba'], loc='upper right')
    
    plt.show()

# %%
##
# 1 < Se situa luego de la primera convolución
# 2 < Se situa luego de la segunda convolucón
# 3 < Se situa antes de pooling
# 4 < Se situa despues del pooling
def create_model(rate,position):
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same',input_shape=x_train.shape[1:],activation='relu'))
    if position==1:
        model.add(Dropout(rate))
    model.add(Conv2D(32, (3, 3),padding='same',activation='relu'))
    if position==2 or position==3:
        model.add(Dropout(rate))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    if position==4:
        model.add(Dropout(rate))
    model.add(Conv2D(64, (3, 3),padding='same',activation='relu'))
    model.add(Conv2D(64, (3, 3),padding='same',activation='relu'))
    if position==3:
        model.add(Dropout(rate))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    if position==3 or position==4:
        model.add(Dropout(rate))
    model.add(Flatten())
    model.add(Dense(1024,activation='relu'))
    model.add(Dropout(0.5))
    #El error era porque faltaba la capa de salida, por lo cual se agrega una softmax de 100 dado a las 100 categorias
    model.add(Dense(100,activation='softmax'))
    model.summary()
    model.compile(loss='categorical_crossentropy', optimizer=optimizer_, metrics=['accuracy'])
    return model

# %%
rates = [0.15,0.2,0.25]

# %% [markdown]
# Dropout por defecto con valor 0.25

# %%
history1 = []
score1 = []
for case in [1,2,3,4]:
    model1 = create_model(0.25,case)
    history1.append(model1.fit(x_train, y_train, batch_size=128,epochs=15,verbose=0,validation_data=(x_test,y_test)))
    score1.append(model1.evaluate(x_test, y_test,verbose=0)[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 8, 8, 64)          0
# ...

# %%
print(len(history1))
# Out:
# 4

# %%
plot_data(history1,'Experimento con Dropout 0.25')

# %% [markdown]
# Droput con valor 0.15

# %%
history2 = []
score2 = []
for case in [1,2,3,4]:
    model2 = create_model(0.15,case)
    history2.append(model2.fit(x_train, y_train, batch_size=128,epochs=15,verbose=0,validation_data=(x_test,y_test)))
    score2.append(model2.evaluate(x_test, y_test,verbose=0)[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_65 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_66 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_67 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_34 (MaxPooling (None, 8, 8, 64)          0
# ...

# %%
plot_data(history2,'Experimento con Dropout 0.15')

# %% [markdown]
# Dropout con valor 0.20

# %%
history3 = []
score3 = []
for case in [1,2,3,4]:
    model3 = create_model(0.25,case)
    history3.append(model3.fit(x_train, y_train, batch_size=128,epochs=15,verbose=0,validation_data=(x_test,y_test)))
    score3.append(model3.evaluate(x_test, y_test,verbose=0)[1])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_81 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_82 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_41 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_83 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_84 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_42 (MaxPooling (None, 8, 8, 64)          0
# ...

# %%
plot_data(history3,'Experimento con Dropout 0.20')

# %% [markdown]
# Como se observa, los casos donde el dropout favorece de mejor forma al modelo es cuando esta
#  > Se situa antes de pooling
#
#  > Se situa despues del pooling
#
# dado que cuando se situa luego de la primera convolución ose situa luego de la segunda convolucón el comportamiento es similar al caso que no tiene dropout

# %% [markdown]
# #### Sección c) Como pre entrenamiento de la misma red definida en a) de una manera no supervisada se trabajará con un autoencoder convolucional, el cual no necesita etiqueta de los datos por lo que se puede aprovechar de transferir lo aprendido con datos sin conocer si pertenecen a la misma categoría o no. Comente y analice si esto mejora lo visto en a). *Utilice todas las imágenes no etiquetadas que desee*.

# %%
hidden_layer1=32
activation_1='relu'
hidden_layer2 = 32
decoder_activation = 'relu'
activation_2 = 'relu'
decoder_activation2 = 'relu'
loss_ = 'categorical_crossentropy'

# %%
from keras.layers import Input
from keras.models import Model

# %%
###BUILD AUTOENCODER1
input_img = Input(shape=x_train.shape[1:])
encoded1 = Conv2D(hidden_layer1, (3, 3),activation=activation_1,padding='same')(input_img)
decoded1 = Conv2D(3, (3, 3), activation=decoder_activation, padding='same')(encoded1)
autoencoder1 = Model(input_img, decoded1)
autoencoder1.compile(optimizer='adam', loss=loss_)
autoencoder1.summary()
autoencoder1.fit(x_train, x_train, epochs=15, batch_size=128,validation_data=(x_test, x_test))
autoencoder1.save('autoencoder_layer1.h5')
###BUILD AUTOENCODER2
encoded1 = autoencoder1.layers[1](autoencoder1.input)
#AUTOENCODER2
encoded2 = Conv2D(hidden_layer2,(3, 3), activation=activation_2, padding='same')(encoded1) 
decoded2 = Conv2D(hidden_layer1,(3, 3), activation=decoder_activation2,padding='same')(encoded2) 
#finish AUTOENCODER2
decoded1 = autoencoder1.layers[-1](decoded2)
autoencoder2 = Model(autoencoder1.input, decoded1) #all model
#autoencoder1 set fixed
autoencoder2.layers[1].trainable=False
autoencoder2.layers[-1].trainable=False
autoencoder2.compile(optimizer='adam', loss=loss_)
autoencoder2.summary()
autoencoder2.fit(x_train, x_train, epochs=10, batch_size=128,validation_data=(x_test, x_test))
autoencoder2.save('autoencoder_layer2.h5')
#FINE TUNNING
model = Sequential()
model.add(Conv2D(hidden_layer1,(3, 3),padding='same',activation=activation_1,input_shape=x_train.shape[1:]))
model.layers[-1].set_weights(autoencoder1.layers[1].get_weights())
model.add(Conv2D(hidden_layer2, (3, 3),padding='same',activation=activation_2))
model.layers[-1].set_weights(autoencoder2.layers[2].get_weights())
model.add(MaxPooling2D(pool_size=(2, 2)))
#rest of the model
model.add(Conv2D(64, (3, 3),padding='same',activation='relu'))
model.add(Conv2D(64, (3, 3),padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(1024,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(100,activation='softmax'))
model.summary()
optimizer_ = keras.optimizers.SGD(lr=0.01,momentum=0.9)
model.compile(loss='categorical_crossentropy', optimizer=optimizer_, metrics=['accuracy'])
aehistory = model.fit(x_train, y_train, batch_size=128,epochs=15,verbose=1, validation_data=(x_test, y_test))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 3)         867
# ...
# Total params: 1,763
# Trainable params: 1,763
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 6s 127us/step - loss: 1.8206 - val_loss: 1.5454
# Epoch 2/15
# 50000/50000 [==============================] - 6s 123us/step - loss: 1.5414 - val_loss: 1.5444
# Epoch 3/15
# 50000/50000 [==============================] - 6s 120us/step - loss: 1.5410 - val_loss: 1.5448
# Epoch 4/15
# ...

# %%
plt.close()
fig, (loss_ax, acc_ax) = plt.subplots(1,2,sharex=True,figsize=(16,4))
loss_ax.scatter(aehistory.epoch,aehistory.history['loss'])
loss_ax.scatter(aehistory.epoch,aehistory.history['val_loss'])
loss_ax.plot(aehistory.history['loss'], label='loss')
loss_ax.plot(aehistory.history['val_loss'], label='val_loss')
acc_ax.scatter(aehistory.epoch,aehistory.history['acc'])
acc_ax.scatter(aehistory.epoch,aehistory.history['val_acc'])
acc_ax.plot(aehistory.history['acc'], label='acc')
acc_ax.plot(aehistory.history['val_acc'], label='val_acc')
acc_ax.legend()
loss_ax.legend()
plt.show()

# %% [markdown]
# En comparación de lo visto en a), no se aprecia una mejora evidente los gráficos parecieran ser los mismo. por lo que se grafican lado a lado

# %%
plt.close()
fig, (loss_ax, acc_ax) = plt.subplots(1,2,sharex=True,figsize=(16,4))
loss_ax.scatter(aehistory.epoch,aehistory.history['loss'])
loss_ax.scatter(aehistory.epoch,aehistory.history['val_loss'])
loss_ax.plot(aehistory.history['loss'], label='loss modelo ae')
loss_ax.plot(aehistory.history['val_loss'], label='val_loss modelo ae')
acc_ax.scatter(aehistory.epoch,aehistory.history['acc'])
acc_ax.scatter(aehistory.epoch,aehistory.history['val_acc'])
acc_ax.plot(aehistory.history['acc'], label='acc modelo ae')
acc_ax.plot(aehistory.history['val_acc'], label='val_acc modelo ae')

loss_ax.scatter(history['model_a'][0].epoch,history['model_a'][0].history['loss'])
loss_ax.scatter(history['model_a'][0].epoch,history['model_a'][0].history['val_loss'])
loss_ax.plot(history['model_a'][0].history['loss'], label='loss modelo a')
loss_ax.plot(history['model_a'][0].history['val_loss'], label='val_loss modelo a')
acc_ax.scatter(history['model_a'][0].epoch,history['model_a'][0].history['acc'])
acc_ax.scatter(history['model_a'][0].epoch,history['model_a'][0].history['val_acc'])
acc_ax.plot(history['model_a'][0].history['acc'], label='acc modelo a')
acc_ax.plot(history['model_a'][0].history['val_acc'], label='val_acc modelo a')

acc_ax.legend()
loss_ax.legend()

plt.show()

# %% [markdown]
# Efectivamente, son muy parecidos en terminos de medidas vs epoch, y en cuanto a tiempos ambos rondan los 4 minutos, la ventaja puede estar del lado del auto encoder cuando ya se tienen los pesos entrenados previamente lo que reduce el tiempo de ejecución en comparación al modelo a).

# %% [markdown]
# #### Sección d) Otra forma de hacer lo que se conoce como *transfer learning* es utilizar el conocimiento (los parámetros) aprendido por una red entrenada con millones de imágenes, y tomar estos parámetros como los pre entrenados. Para esto se utilizará el modelo VGG16 [7] proporcionado a través de la interfaz de keras. Visualice el modelo y sus 23 capas. Para esta instancia se utilizará todo lo aprendido por las capas convolucionales, es decir, se eliminan las capas densas del modelo y se agregan unas nuevas a ser entrenadas desde cero.

# %%
from keras.applications import VGG16
#LOAD PRETRAINED MODEL 
input_tensor=Input(shape=x_train.shape[1:])
modelVGG = VGG16(weights='imagenet', include_top=False,input_tensor=input_tensor )
modelVGG.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# ...

# %%
features_train = modelVGG.predict(x_train)
features_test = modelVGG.predict(x_test)

# %% [markdown]
# #### Sección e) Entrene esta red agregando una capa densa de 1024 neuronas seguido de un dropout de 0.5, finalmente es necesario agregar la capa de clasificación para las 100 clases. Utilice la misma configuración del optimizador para que las comparaciones sean válidas. Entrene unicamente por 10 *epochs* ¿Qué sucede? Comente.

# %%
#history = defaultdict(list)

# %%
epochs_ = 10

# %%
model = Sequential()
model.add(Flatten(input_shape=features_train.shape[1:]))
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
#El error era porque faltaba la capa de salida, por lo cual se agrega una softmax de 100 dado a las 100 categorias
model.add(Dense(100,activation='softmax'))


model.compile(optimizer=optimizer_,loss='categorical_crossentropy', metrics=['accuracy'])
start_e = time.time()
history['tf_wt_bn'].append(model.fit(features_train, y_train,epochs=epochs_, batch_size=128,verbose=1,validation_data=(features_test,y_test)))
end_e = time.time()-start_e
history['tf_wt_bn'].append(end_e)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 2s 32us/step - loss: 3.9603 - acc: 0.1090 - val_loss: 3.4004 - val_acc: 0.2076
# Epoch 2/15
# 50000/50000 [==============================] - 1s 26us/step - loss: 3.3550 - acc: 0.1960 - val_loss: 3.1183 - val_acc: 0.2510
# Epoch 3/15
# 50000/50000 [==============================] - 1s 24us/step - loss: 3.1586 - acc: 0.2313 - val_loss: 2.9852 - val_acc: 0.2696
# Epoch 4/15
# 50000/50000 [==============================] - 1s 24us/step - loss: 3.0462 - acc: 0.2549 - val_loss: 2.9159 - val_acc: 0.2841
# Epoch 5/15
# 50000/50000 [==============================] - 1s 24us/step - loss: 2.9642 - acc: 0.2689 - val_loss: 2.8484 - val_acc: 0.2992
# Epoch 6/15
# 50000/50000 [==============================] - 1s 24us/step - loss: 2.9101 - acc: 0.2800 - val_loss: 2.7995 - val_acc: 0.3067
# Epoch 7/15
# ...

# %%
score = model.evaluate(features_test, y_test,verbose=0)
history['tf_wt_bn'].append(score)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.3428

# %%
plt.close()
fig, (loss_ax, acc_ax) = plt.subplots(1,2,sharex=True,figsize=(16,4))
loss_ax.scatter(history['tf_wt_bn'][0].epoch,history['tf_wt_bn'][0].history['loss'])
loss_ax.scatter(history['tf_wt_bn'][0].epoch,history['tf_wt_bn'][0].history['val_loss'])
loss_ax.plot(history['tf_wt_bn'][0].history['loss'], label='loss')
loss_ax.plot(history['tf_wt_bn'][0].history['val_loss'], label='val_loss')
acc_ax.scatter(history['tf_wt_bn'][0].epoch,history['tf_wt_bn'][0].history['acc'])
acc_ax.scatter(history['tf_wt_bn'][0].epoch,history['tf_wt_bn'][0].history['val_acc'])
acc_ax.plot(history['tf_wt_bn'][0].history['acc'], label='acc')
acc_ax.plot(history['tf_wt_bn'][0].history['val_acc'], label='val_acc')
acc_ax.legend()
loss_ax.legend()
plt.show()

# %% [markdown]
# Los resultados, no indican la presencia de overfitting, pero tampoco un gran incremento en la accuracy.

# %%
history['tf_wt_bn2'].append(model.fit(features_train, y_train,epochs=15, batch_size=128,verbose=1,validation_data=(features_test,y_test)))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.6190 - acc: 0.3334 - val_loss: 2.5902 - val_acc: 0.3500
# Epoch 2/15
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.5979 - acc: 0.3392 - val_loss: 2.5862 - val_acc: 0.3481
# Epoch 3/15
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.5816 - acc: 0.3425 - val_loss: 2.5762 - val_acc: 0.3492
# Epoch 4/15
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.5660 - acc: 0.3447 - val_loss: 2.5961 - val_acc: 0.3469
# Epoch 5/15
# 50000/50000 [==============================] - 1s 24us/step - loss: 2.5472 - acc: 0.3493 - val_loss: 2.5547 - val_acc: 0.3559
# Epoch 6/15
# 50000/50000 [==============================] - 1s 24us/step - loss: 2.5350 - acc: 0.3523 - val_loss: 2.5393 - val_acc: 0.3573
# Epoch 7/15
# ...

# %%
plt.close()
fig, (loss_ax, acc_ax) = plt.subplots(1,2,sharex=True,figsize=(16,4))
loss_ax.scatter(history['tf_wt_bn2'][0].epoch,history['tf_wt_bn2'][0].history['loss'])
loss_ax.scatter(history['tf_wt_bn2'][0].epoch,history['tf_wt_bn2'][0].history['val_loss'])
loss_ax.plot(history['tf_wt_bn2'][0].history['loss'], label='loss')
loss_ax.plot(history['tf_wt_bn2'][0].history['val_loss'], label='val_loss')
acc_ax.scatter(history['tf_wt_bn2'][0].epoch,history['tf_wt_bn2'][0].history['acc'])
acc_ax.scatter(history['tf_wt_bn2'][0].epoch,history['tf_wt_bn2'][0].history['val_acc'])
acc_ax.plot(history['tf_wt_bn2'][0].history['acc'], label='acc')
acc_ax.plot(history['tf_wt_bn2'][0].history['val_acc'], label='val_acc')
acc_ax.legend()
loss_ax.legend()
plt.show()

# %% [markdown]
# Al correr el modelo con 15 epochs se tiene que el patron se mantiene.

# %% [markdown]
# #### Sección f)
# Agregue una capa de normalización (*Batch Normalization* [8]) de las activaciones en las capas densas, esto es, restar por la media del batch y dividir por la desviación estándar. Vuelva a entrenar el modelo con la misma configuración pero ahora por **15 *epochs***. Comente lo observado y compare las curvas de convergencia con los modelos anteriores ¿Por qué esto mejora a lo presentado en e)? Realice los mismos gráficos que en a) a través del número de *epochs* y comente sobre el tiempo de ejecución de este entrenamiento.

# %%
from keras.layers import BatchNormalization
epochs_ = 15

# %%
model_f = Sequential()
model_f.add(Flatten(input_shape=features_train.shape[1:]))
model_f.add(BatchNormalization())
model_f.add(Dense(1024, activation='relu'))
model_f.add(BatchNormalization())
model_f.add(Dropout(0.5))
model_f.add(Dense(100,activation='softmax'))
model_f.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_10 (Flatten)         (None, 512)               0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_19 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 100)               102500
# ...
# Total params: 633,956
# Trainable params: 630,884
# Non-trainable params: 3,072
# _________________________________________________________________

# %%
optimizer_ = SGD(lr=0.01,momentum=0.9)
start_time= time.time()
model_f.compile(optimizer=optimizer_,loss='categorical_crossentropy', metrics=['accuracy'])
end_time = time.time()-start_time
history['tf_w_bn'].append(model_f.fit(features_train, y_train,epochs=epochs_, batch_size=128,verbose=1,validation_data=(features_test,y_test)))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 2s 48us/step - loss: 3.7406 - acc: 0.2031 - val_loss: 2.8716 - val_acc: 0.3079
# Epoch 2/15
# 50000/50000 [==============================] - 2s 32us/step - loss: 2.9633 - acc: 0.2905 - val_loss: 2.7080 - val_acc: 0.3362
# Epoch 3/15
# 50000/50000 [==============================] - 2s 32us/step - loss: 2.7381 - acc: 0.3238 - val_loss: 2.6384 - val_acc: 0.3460
# Epoch 4/15
# 50000/50000 [==============================] - 2s 31us/step - loss: 2.5902 - acc: 0.3476 - val_loss: 2.6111 - val_acc: 0.3577
# Epoch 5/15
# 50000/50000 [==============================] - 2s 32us/step - loss: 2.4794 - acc: 0.3683 - val_loss: 2.5736 - val_acc: 0.3684
# Epoch 6/15
# 50000/50000 [==============================] - 2s 33us/step - loss: 2.3976 - acc: 0.3832 - val_loss: 2.5652 - val_acc: 0.3722
# Epoch 7/15
# ...

# %%
plt.close()
fig, (loss_ax, acc_ax) = plt.subplots(1,2,sharex=True,figsize=(16,4))
loss_ax.scatter(history['tf_w_bn'][0].epoch,history['tf_w_bn'][0].history['loss'])
loss_ax.scatter(history['tf_w_bn'][0].epoch,history['tf_w_bn'][0].history['val_loss'])
loss_ax.plot(history['tf_w_bn'][0].history['loss'], label='loss')
loss_ax.plot(history['tf_w_bn'][0].history['val_loss'], label='val_loss')
acc_ax.scatter(history['tf_w_bn'][0].epoch,history['tf_w_bn'][0].history['acc'])
acc_ax.scatter(history['tf_w_bn'][0].epoch,history['tf_w_bn'][0].history['val_acc'])
acc_ax.plot(history['tf_w_bn'][0].history['acc'], label='acc')
acc_ax.plot(history['tf_w_bn'][0].history['val_acc'], label='val_acc')
acc_ax.legend()
loss_ax.legend()
plt.show()

# %% [markdown]
# Al usar BatchNormalization se empeoró los rasultados, el modelo presenta un fitting mayor al train en comparación al modelo sin BatchNormalization

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3,sharex=True,sharey=True,figsize=(16,4))

ax1.plot(history['tf_wt_bn2'][0].history['loss'], label='loss')
ax1.plot(history['tf_wt_bn2'][0].history['val_loss'], label='val_loss')
ax1.legend()
ax2.plot(history['tf_w_bn'][0].history['loss'], label='loss')
ax2.plot(history['tf_w_bn'][0].history['val_loss'], label='val_loss')
ax2.legend()
ax3.plot(history['model_a'][0].history['loss'], label='loss')
ax3.plot(history['model_a'][0].history['val_loss'], label='val_loss')
ax3.legend()

plt.show()

# %% [markdown]
# #### Sección g)
# > g) Anteriormente se dejaron fijas las capas de convolución de VGG16, ahora experimente comentando sobre la convergencia y el tiempo de ejecución el entrenar la última tanda de convoluciones de VGG16, es decir, tome como punto inicial los pesos pre entrenados de esta red en *Imagenet* y entrenelos para este problema.

# %%
optimizer_ = SGD(lr=0.01, momentum=0.9, decay=1e-6)
epochs_ = 15

# %%
import numpy as np

# %%
#LOAD PRETRAINED MODEL 
input_tensor=Input(shape=x_train.shape[1:])
modelVGG = VGG16(weights='imagenet', include_top=False,input_tensor=input_tensor )
salida_vgg = modelVGG.get_layer('block4_pool').output_shape
model_g = Sequential()
model_g.add(Conv2D(512,(3, 3),input_shape=salida_vgg[1:],activation='relu',padding='same'))
model_g.add(Conv2D(512,(3, 3),activation='relu',padding='same'))
model_g.add(Conv2D(512,(3, 3),activation='relu',padding='same'))
model_g.add(MaxPooling2D((2, 2),strides=(2,2)))    
##dense section
model_g.add(Flatten())
model_g.add(BatchNormalization())
model_g.add(Dense(1024, activation='relu'))
model_g.add(BatchNormalization())
model_g.add(Dropout(0.5))
model_g.add(Dense(100, activation='softmax'))
#delete last 4 layers of VGG16 and transfer the weight to new model
modelVGG.layers.pop() #delete last maxpooling
for i in np.arange(2,-1,-1):
    last = modelVGG.layers.pop() #delete convolutional layers
    model_g.layers[i].set_weights(last.get_weights())

# %%
crop_modelVGG = Model(inputs=modelVGG.input, outputs=modelVGG.layers[-1].output)
features_train = crop_modelVGG.predict(x_train)
features_test = crop_modelVGG.predict(x_test)
#train it
model_g.compile(optimizer=optimizer_,loss='categorical_crossentropy', metrics=['accuracy'])

# %%
start_g = time.time()
history['model_g'].append(model_g.fit(
    features_train,
    y_train,
    epochs=epochs_,
    batch_size=128,
    verbose=1,
    validation_data=(features_test, y_test)))
end_g = time.time() - start_g
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 11s 222us/step - loss: 3.5587 - acc: 0.2060 - val_loss: 3.5374 - val_acc: 0.2332
# Epoch 2/15
# 50000/50000 [==============================] - 9s 189us/step - loss: 2.7436 - acc: 0.3268 - val_loss: 7.0081 - val_acc: 0.0839
# Epoch 3/15
# 50000/50000 [==============================] - 9s 189us/step - loss: 2.4909 - acc: 0.3739 - val_loss: 2.5873 - val_acc: 0.3476
# Epoch 4/15
# 50000/50000 [==============================] - 9s 188us/step - loss: 2.2958 - acc: 0.4100 - val_loss: 2.4915 - val_acc: 0.3689
# Epoch 5/15
# 50000/50000 [==============================] - 9s 188us/step - loss: 2.1695 - acc: 0.4350 - val_loss: 2.2813 - val_acc: 0.4235
# Epoch 6/15
# 50000/50000 [==============================] - 9s 189us/step - loss: 2.0564 - acc: 0.4567 - val_loss: 3.6933 - val_acc: 0.2599
# Epoch 7/15
# ...

# %% [markdown]
# En comparación a los modelos anteriores, al permitir que más capas sean entrenadas, se aumenta el tiempo que tarda por epoch en 7 segundos en promedio.

# %%
print(model_g.evaluate(features_test, y_test,verbose=0)[1])
# Out:
# 0.4525

# %%
plt.close()
fig, (loss_ax, acc_ax) = plt.subplots(1,2,sharex=True,figsize=(16,4))
loss_ax.scatter(history['model_g'][0].epoch,history['model_g'][0].history['loss'])
loss_ax.scatter(history['model_g'][0].epoch,history['model_g'][0].history['val_loss'])
loss_ax.plot(history['model_g'][0].history['loss'], label='loss')
loss_ax.plot(history['model_g'][0].history['val_loss'], label='val_loss')
acc_ax.scatter(history['model_g'][0].epoch,history['model_g'][0].history['acc'])
acc_ax.scatter(history['model_g'][0].epoch,history['model_g'][0].history['val_acc'])
acc_ax.plot(history['model_g'][0].history['acc'], label='acc')
acc_ax.plot(history['model_g'][0].history['val_acc'], label='val_acc')
acc_ax.legend()
loss_ax.legend()
plt.show()

# %% [markdown]
# En presencia de los resultados, se puede decir que el modelo usando la ultima tanda de VGG16 mejora el modelo cero, asi como los modelos anteriormente probados, aun asi existe overfitting en el modelo.
#
# En general, los beneficios vistos al usar transfer learning, no son muchos en accuracy, pero si en el tiempo que toma al modelo en converger, es como si al usar el transfer learning, se partiera cerca de un optimo local.
